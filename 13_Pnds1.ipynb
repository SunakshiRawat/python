# %% [markdown]
# <a href="https://colab.research.google.com/github/SunakshiRawat/python/blob/main/13_Pnds1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import package
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %%
#Our first series
number_series= pd.Series([1,2,3,4,5])
number_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#Same series but with different indices
number_series= pd.Series([1,2,3,4,5], index=['a','b','c','d','e'], name='Number')
number_series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Number, dtype: int64

# %%
print(number_series[0])
print(number_series['a'])
# Out:
# 1
# 1
# <ipython-input-10-43cc7e55b50e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(number_series[0])

# %%
print(number_series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Number, dtype: int64

# %%
#Creating our first DataFrame
some_2D_array = np.random.randint(4,6,(3,4))
first_dataframe = pd.DataFrame(some_2D_array, columns=['AAA','BBB','CCC','DDD'])
first_dataframe
# Out:
#    AAA  BBB  CCC  DDD
# 0    4    4    4    4
# 1    4    5    5    4
# 2    5    5    4    4

# %%
#Lets create the same dataframe but different indices
import pandas as pd
another_dataframe = pd.DataFrame(some_2D_array, columns=['AAA','BBB','CCC','DDD'], index=['First','Second','Third'])
another_dataframe
# Out:
#         AAA  BBB  CCC  DDD
# First     4    4    4    4
# Second    4    5    5    4
# Third     5    5    4    4

# %%
#Initialize the list of lists
list_og_lists=[['Boo',10], ['Baa',20], ['bee',30]]

# %%
#Create the pandas DataFrame
df=pd.DataFrame(list_og_lists, columns=['Name','Age'])
df
# Out:
#   Name  Age
# 0  Boo   10
# 1  Baa   20
# 2  bee   30

# %%
#Store the data in a dictionary
employee_dict = {'Employee Name':['Boo','Baa','bee'], 'Income':[100000,200000,300000]}

# %%
#Create DataFrame and then print it
employee_df = pd.DataFrame(employee_dict)
employee_df
# Out:
#   Employee Name  Income
# 0           Boo  100000
# 1           Baa  200000
# 2           bee  300000

# %%
#Store the data in a dictionary
series_dict = {'First Series':pd.Series([1,2,3,4,5]),
               'Second Series':pd.Series([10,20,30,40,50])}

# %%
#Create the DataFrame using the dictionary
df=pd.DataFrame(series_dict)
df
# Out:
#    First Series  Second Series
# 0             1             10
# 1             2             20
# 2             3             30
# 3             4             40
# 4             5             50

# %%
#Initialize the list of dictionaries
lists_of_dicts=[{'A':1,'B':2,'C':3}, {'A':10,'B':20,'C':30}]

# %%
#Create the DataFrame
lists_of_dicts=[{'A':1,'B':2,'C':3}, {'A':10,'B':20,'C':30}]
df = pd.DataFrame(lists_of_dicts)
df
# Out:
#     A   B   C
# 0   1   2   3
# 1  10  20  30

# %%
#What happens if the number of keys are different in the two dictionaries
list_of_dicts = [{'A':2,'B':3}, {'A':10,'B':20,'c':30}]
df = pd.DataFrame(list_of_dicts, index = ['First', 'Second'])
df
# Out:
#          A   B     c
# First    2   3   NaN
# Second  10  20  30.0

# %%
#other ways
#List of names
actor_names = ['Tom Cruise','Tom Hanks','Brad Pitt']
actor_ages = [40,38,42,np.nan]
list_of_tuples = list(zip(actor_names, actor_ages))

# %%
list_of_tuples = list(zip(actor_names, actor_ages))

# %%
#Comnverting the list of tuples into pandas DataFrame
actor_df = pd.DataFrame(list_of_tuples, columns=['Name','Age'])
actor_df
# Out:
#          Name  Age
# 0  Tom Cruise   40
# 1   Tom Hanks   38
# 2   Brad Pitt   42

# %%
list(actor_df.index)
# Out:
# [0, 1, 2]

# %%
#Create an array of shape(3,5)
our_array = np.random.randn(3,5)
df = pd.DataFrame(our_array, columns=['A','B','C','D','E'])
df
# Out:
#           A         B         C         D         E
# 0 -0.527155 -0.171074  0.274928  0.061146  0.249225
# 1 -0.280454  1.284142 -0.023711  0.596270 -0.579296
# 2 -0.023663 -0.879854  0.770134 -0.460989 -0.197908

# %%
#We can use the head() method
df.head()
# Out:
#           A         B         C         D         E
# 0 -0.527155 -0.171074  0.274928  0.061146  0.249225
# 1 -0.280454  1.284142 -0.023711  0.596270 -0.579296
# 2 -0.023663 -0.879854  0.770134 -0.460989 -0.197908

# %%
#We can also print the first 10 rows
df.head(1)
# Out:
#           A         B         C         D         E
# 0 -0.527155 -0.171074  0.274928  0.061146  0.249225

# %%
df.tail()
# Out:
#           A         B         C         D         E
# 0 -0.527155 -0.171074  0.274928  0.061146  0.249225
# 1 -0.280454  1.284142 -0.023711  0.596270 -0.579296
# 2 -0.023663 -0.879854  0.770134 -0.460989 -0.197908

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
actor_df
# Out:
#          Name  Age
# 0  Tom Cruise   40
# 1   Tom Hanks   38
# 2   Brad Pitt   42

# %%
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
actor_df
# Out:
#          Name  Age
# 0  Tom Cruise   40
# 1   Tom Hanks   38
# 2   Brad Pitt   42

# %%
df1=actor_df.rename(columns={'Name':'Actor Name','Age':'Actor Age'}, inplace=False)
df1
# Out:
#    Actor Name  Actor Age
# 0  Tom Cruise         40
# 1   Tom Hanks         38
# 2   Brad Pitt         42

# %%
employee_df
# Out:
#   Employee Name  Income
# 0           Boo  100000
# 1           Baa  200000
# 2           bee  300000

# %%
employee_df.rename(columns = {'Employee Name':'Name','Income':'($)'}, inplace=True)
employee_df
# Out:
#   Name     ($)
# 0  Boo  100000
# 1  Baa  200000
# 2  bee  300000

# %%
employee_df = employee_df.rename({'Employee Name':'Name','Income':'($)'}, axis=1)
employee_df
# Out:
#   Name     ($)
# 0  Boo  100000
# 1  Baa  200000
# 2  bee  300000
